# %% [markdown]
# # 3주차-1 과제(05-numerical-features)

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from matplotlib import rcParams, pyplot as plt
import numpy as np
import pandas as pd
from pathlib import Path
import seaborn as sns
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from warnings import simplefilter
import random

# %%
rcParams['figure.figsize'] = (16, 8)
plt.style.use('fivethirtyeight')
simplefilter('ignore')

# %%
data_dir = Path('./input/')
trn_file = data_dir / 'train.csv'
seed = 42
df = pd.read_csv(trn_file, index_col=0)
print(df.shape)
df.head()
# Out:
# (320000, 19)
#             u          g          r          i          z  redshift   dered_u  \
# id
# 0   23.263956  20.336773  19.009500  17.672439  16.939607 -0.000081  23.12426
# 1   15.052147  14.061969  13.452418  13.268450  13.168941  0.004506  14.96642
# 2   16.786385  15.825426  15.536318  15.393535  15.350032  0.000472  16.60765
# 3   25.660638  21.188727  20.221158  19.894949  19.634649  0.000006  25.35365
# 4   24.453429  20.699170  19.042368  18.324152  17.982649 -0.000033  23.77140
#
#      dered_g   dered_r   dered_i   dered_z  nObserve  nDetect  airmass_u  \
# id
# 0   20.25779  18.95512  17.63211  16.90894        18       18   1.189764
# 1   14.00452  13.41139  13.23625  13.13468         1        1   1.253254
# 2   15.68659  15.44004  15.32173  15.29608         2        2   1.022499
# 3   20.99465  20.08727  19.79465  19.55518         4        3   1.205399
# 4   20.43384  18.86299  18.19028  17.87592        13       12   1.193946
#
#     airmass_g  airmass_r  airmass_i  airmass_z  class
# id
# 0    1.190681   1.188979   1.189355   1.190206      0
# 1    1.257836   1.248762   1.250997   1.255533      1
# 2    1.024105   1.020983   1.021730   1.023291      0
# 3    1.206058   1.204874   1.205120   1.205712      0
# 4    1.194285   1.193738   1.193826   1.194099      0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 320000 entries, 0 to 319999
# Data columns (total 19 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   u          320000 non-null  float64
#  1   g          320000 non-null  float64
#  2   r          320000 non-null  float64
#  3   i          320000 non-null  float64
#  4   z          320000 non-null  float64
#  5   redshift   320000 non-null  float64
#  6   dered_u    320000 non-null  float64
#  7   dered_g    320000 non-null  float64
#  8   dered_r    320000 non-null  float64
#  9   dered_i    320000 non-null  float64
#  10  dered_z    320000 non-null  float64
#  11  nObserve   320000 non-null  int64
#  12  nDetect    320000 non-null  int64
#  13  airmass_u  320000 non-null  float64
#  14  airmass_g  320000 non-null  float64
#  15  airmass_r  320000 non-null  float64
#  16  airmass_i  320000 non-null  float64
#  17  airmass_z  320000 non-null  float64
#  18  class      320000 non-null  int64
# dtypes: float64(16), int64(3)
# memory usage: 48.8 MB

# %%
df.describe()
# Out:
#                    u              g              r              i  \
# count  320000.000000  320000.000000  320000.000000  320000.000000
# mean       19.852429      18.376837      17.735761      17.174226
# std         1.945548      31.110759       1.466242      52.561464
# min       -17.687512  -17555.365606       7.731354  -23955.817764
# 25%        18.724150      17.474851      16.877190      16.523876
# 50%        19.419439      18.140528      17.525850      17.149736
# 75%        20.432092      19.073172      18.428089      18.007435
# max        58.623328      46.338272      72.009662      50.164052
#
#                    z       redshift        dered_u        dered_g  \
# count  320000.000000  320000.000000  320000.000000  320000.000000
# mean       16.875187       0.058308      19.628874      18.227087
# std        57.146264       0.575457       1.923586      17.786568
# min    -23955.817764    -166.048260     -42.837530   -9999.000000
# 25%        16.288890       0.000036      18.563598      17.348370
# 50%        16.917610       0.047129      19.264635      18.022410
# 75%        17.728924       0.094597      20.197603      18.888443
# max        52.612664      62.323343      30.777850      30.613170
#
#              dered_r        dered_i        dered_z       nObserve  \
# count  320000.000000  320000.000000  320000.000000  320000.000000
# mean       17.615434      17.152347      16.869277       6.332700
# std         1.473020      25.075760      35.436549       8.881129
# min       -16.380230   -9999.000000   -9999.000000       1.000000
# 25%        16.787138      16.453048      16.234063       1.000000
# 50%        17.443415      17.087370      16.869390       2.000000
# 75%        18.291078      17.906960      17.655653       5.000000
# max        31.957200      32.016220      30.781270      44.000000
#
#              nDetect      airmass_u      airmass_g      airmass_r  \
# count  320000.000000  320000.000000  320000.000000  320000.000000
# mean        6.138816       1.175763       1.176528       1.175131
# std         8.551634       0.116297       0.118065       0.114723
# min         1.000000       1.000059       1.000012       1.000157
# 25%         1.000000       1.088220       1.088448       1.087763
# 50%         2.000000       1.179350       1.179235       1.179375
# 75%         5.000000       1.227540       1.225990       1.229236
# max        42.000000       2.050775       2.080287       2.022134
#
#            airmass_i      airmass_z          class
# count  320000.000000  320000.000000  320000.000000
# mean        1.175430       1.176128       1.116322
# std         0.115485       0.117156       0.923455
# min         1.000105       1.000027       0.000000
# 25%         1.088021       1.088299       0.000000
# 50%         1.179377       1.179303       1.000000
# 75%         1.228599       1.226757       2.000000
# max         2.036329       2.065390       2.000000

# %%
df.fillna(0, inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 320000 entries, 0 to 319999
# Data columns (total 19 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   u          320000 non-null  float64
#  1   g          320000 non-null  float64
#  2   r          320000 non-null  float64
#  3   i          320000 non-null  float64
#  4   z          320000 non-null  float64
#  5   redshift   320000 non-null  float64
#  6   dered_u    320000 non-null  float64
#  7   dered_g    320000 non-null  float64
#  8   dered_r    320000 non-null  float64
#  9   dered_i    320000 non-null  float64
#  10  dered_z    320000 non-null  float64
#  11  nObserve   320000 non-null  int64
#  12  nDetect    320000 non-null  int64
#  13  airmass_u  320000 non-null  float64
#  14  airmass_g  320000 non-null  float64
#  15  airmass_r  320000 non-null  float64
#  16  airmass_i  320000 non-null  float64
#  17  airmass_z  320000 non-null  float64
#  18  class      320000 non-null  int64
# dtypes: float64(16), int64(3)
# memory usage: 48.8 MB

# %%
df.describe()
# Out:
#                    u              g              r              i  \
# count  320000.000000  320000.000000  320000.000000  320000.000000
# mean       19.852429      18.376837      17.735761      17.174226
# std         1.945548      31.110759       1.466242      52.561464
# min       -17.687512  -17555.365606       7.731354  -23955.817764
# 25%        18.724150      17.474851      16.877190      16.523876
# 50%        19.419439      18.140528      17.525850      17.149736
# 75%        20.432092      19.073172      18.428089      18.007435
# max        58.623328      46.338272      72.009662      50.164052
#
#                    z       redshift        dered_u        dered_g  \
# count  320000.000000  320000.000000  320000.000000  320000.000000
# mean       16.875187       0.058308      19.628874      18.227087
# std        57.146264       0.575457       1.923586      17.786568
# min    -23955.817764    -166.048260     -42.837530   -9999.000000
# 25%        16.288890       0.000036      18.563598      17.348370
# 50%        16.917610       0.047129      19.264635      18.022410
# 75%        17.728924       0.094597      20.197603      18.888443
# max        52.612664      62.323343      30.777850      30.613170
#
#              dered_r        dered_i        dered_z       nObserve  \
# count  320000.000000  320000.000000  320000.000000  320000.000000
# mean       17.615434      17.152347      16.869277       6.332700
# std         1.473020      25.075760      35.436549       8.881129
# min       -16.380230   -9999.000000   -9999.000000       1.000000
# 25%        16.787138      16.453048      16.234063       1.000000
# 50%        17.443415      17.087370      16.869390       2.000000
# 75%        18.291078      17.906960      17.655653       5.000000
# max        31.957200      32.016220      30.781270      44.000000
#
#              nDetect      airmass_u      airmass_g      airmass_r  \
# count  320000.000000  320000.000000  320000.000000  320000.000000
# mean        6.138816       1.175763       1.176528       1.175131
# std         8.551634       0.116297       0.118065       0.114723
# min         1.000000       1.000059       1.000012       1.000157
# 25%         1.000000       1.088220       1.088448       1.087763
# 50%         2.000000       1.179350       1.179235       1.179375
# 75%         5.000000       1.227540       1.225990       1.229236
# max        42.000000       2.050775       2.080287       2.022134
#
#            airmass_i      airmass_z          class
# count  320000.000000  320000.000000  320000.000000
# mean        1.175430       1.176128       1.116322
# std         0.115485       0.117156       0.923455
# min         1.000105       1.000027       0.000000
# 25%         1.088021       1.088299       0.000000
# 50%         1.179377       1.179303       1.000000
# 75%         1.228599       1.226757       2.000000
# max         2.036329       2.065390       2.000000

# %%
sns.pairplot(df.sample(n=10000), vars=['r', 'dered_r'], hue='class', size=5)

# %%
target_col = 'class'
pred_col = 'pred'
num_cols = [x for x in df.columns if df[x].dtype in [np.int64] and x != target_col]
print(num_cols)
# Out:
# ['nObserve', 'nDetect']

# %%
df.nObserve.class.hist(bins=50)
# Out:
#   File "<ipython-input-29-d418bafad277>", line 1
#     df.nObserve.class.hist(bins=50)
#                 ^
# SyntaxError: invalid syntax

# %%
sns.pairplot(data=df, vars=num_cols + [target_col], size=5)

# %%
df.corr().style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_07cf7b84_f8a9_11ea_9d3a_0c7a1589118crow0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_07cf7b84_f8a9_11ea_9d3a_0c7a1589118crow0_col1 {
#             background-color:  #f5eef6;
#             color:  #000000;
#         }    #T_07cf7b84_f8a9_11ea_9d3a_0c7a1589118crow0_col2 {
#             background-color:  #045b8e;
#             color:  #f1f1f1;
#         }    #T_07cf7b84_f8a9_11ea_9d3a_0c7a1589118crow0_col3 {
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }    #T_07cf7b84_f8a9_11ea_9d3a_0c7a1589118crow0_col4 {
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }    #T_07cf7b84_f8a9_11ea_9d3a_0c7a1589118crow0_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_07cf7b84_f8a9_11ea_9d3a_0c7a1589118crow0_col6 {
#             background-color:  #03456c;
#             color:  #f1f1f1;
#         }    #T_07cf7b84_f8a9_11ea_9d3a_0c7a1589118crow0_col7 {
#             background-color:  #efe9f3;
#             color:  #000000;
#         }    #T_07cf7b84_f8a9_11ea_9d3a_0c7a1589118crow0_col8 {
#             background-color:  #046097;
#             color:  #f1f1f1;
#         }    #T_07cf7b84_f8a9_11ea_9d3a_0c7a1589118crow0_col9 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_07cf7b84_f8a9_11ea_9d3a_0c7a1589118crow0_col10 {
#             background-color:  #faf2f8;
#             color:  #000000;
#         }    #T_07cf7b84_f8a9_11ea_9d3a_0c7a1589118crow0_col11 {
#             background-color:  #a9bfdc;
#             color:  #000000;
#         }    #T_07cf7b84_f8a9_11ea_9d3a_0c7a1589118crow0_col12 {
#             background-color:  #abbfdc;
#             color:  #000000;
#         }    #T_07cf7b84_f8a9_11ea_9d3a_0c7a1589118crow0_col13 {
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }    #T_07cf7b84_f8a9_11ea_9d3a_0c7a1589118crow0_col14 {
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }    #T_07cf7b84_f8a9_11ea_9d3a_0c7a1589118crow0_col15 {
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }    #T_07cf7b84_f8a9_11ea_9d3a_0c7a1589118crow0_col16 {
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }    #T_07cf7b84_f8a9_11ea_9d3a_0c7a1589118crow0_col17 {
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }    #T_07cf7b84_f8a9_11ea_9d3a_0c7a1589118crow0_col18 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_07cf7b84_f8a9_11ea_9d3a_0c7a1589118crow1_col0 {
#             background-color:  #bcc7e1;
#             color:  #000000;
#         }    #T_07cf7b84_f8a9_11ea_9d3a_0c7a1589118crow1_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_07cf7b84_f8a9_11ea_9d3a_0c7a1589118crow1_col2 {
#             background-color:  #bcc7e1;
#             color:  #000000;
#         }    #T_07cf7b84_f8a9_11ea_9d3a_0c7a1589118crow1_col3 {
#             background-color:  #4496c3;
#             color:  #000000;
#         }    #T_07cf7b84_f8a9_11ea_9d3a_0c7a1589118crow1_col4 {
#             background-color:  #5c9fc9;
#             color:  #000000;
#         }    #T_07cf7b84_f8a9_11ea_9d3a_0c7a1589118crow1_col5 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_07cf7b84_f8a9_11ea_9d3a_0c7a1589118crow1_col6 {
#             background-color:  #c4cbe3;
#             color:  #000000;
#         }    #T_07cf7b84_f8a9_11ea_9d3a_0c7a1589118crow1_col7 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_07cf7b84_f8a9_11ea_9d3a_0c7a1589118crow1_col8 {
#             background-color:  #c2cbe2;
#             color:  #000000;
#         }    #T_07cf7b84_f8a9_11ea_9d3a_0c7a1589118crow1_col9 {
#             background-color:  #1379b5;
#             color:  #f1f1f1;
#         }    #T_07cf7b84_f8a9_11ea_9d3a_0c7a1589118crow1_col10 {
#             background-color:  #71a8ce;
#             color:  #000000;
#         }    #T_07cf7b84_f8a9_11ea_9d3a_0c7a1589118crow1_col11 {
#             background-color:  #dfddec;
#             color:  #000000;
#         }    #T_07cf7b84_f8a9_11ea_9d3a_0c7a1589118crow1_col12 {
#             background-color:  #dedcec;
#             color:  #000000;
#         }    #T_07cf7b84_f8a9_11ea_9d3a_0c7a1589118crow1_col13 {
#             background-color:  #f4eef6;
#             color:  #000000;
#         }    #T_07cf7b84_f8a9_11ea_9d3a_0c7a1589118crow1_col14 {
#             background-color:  #f4eef6;
#             color:  #000000;
#         }    #T_07cf7b84_f8a9_11ea_9d3a_0c7a1589118crow1_col15 {
#             background-color:  #f4eef6;
#             color:  #000000;
#         }    #T_07cf7b84_f8a9_11ea_9d3a_0c7a1589118crow1_col16 {
#             background-color:  #f4eef6;
#             color:  #000000;
#         }    #T_07cf7b84_f8a9_11ea_9d3a_0c7a1589118crow1_col17 {
#             background-color:  #f4eef6;
#             color:  #000000;
#         }    #T_07cf7b84_f8a9_11ea_9d3a_0c7a1589118crow1_col18 {
#             background-color:  #cdd0e5;
#             color:  #000000;
#         }    #T_07cf7b84_f8a9_11ea_9d3a_0c7a1589118crow2_col0 {
#             background-color:  #045b8e;
#             color:  #f1f1f1;
#         }    #T_07cf7b84_f8a9_11ea_9d3a_0c7a1589118crow2_col1 {
#             background-color:  #f5eef6;
#             color:  #000000;
#         }    #T_07cf7b84_f8a9_11ea_9d3a_0c7a1589118crow2_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_07cf7b84_f8a9_11ea_9d3a_0c7a1589118crow2_col3 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_07cf7b84_f8a9_11ea_9d3a_0c7a1589118crow2_col4 {
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }    #T_07cf7b84_f8a9_11ea_9d3a_0c7a1589118crow2_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_07cf7b84_f8a9_11ea_9d3a_0c7a1589118crow2_col6 {
#             background-color:  #045e93;
#             color:  #f1f1f1;
#         }    #T_07cf7b84_f8a9_11ea_9d3a_0c7a1589118crow2_col7 {
#             background-color:  #eee9f3;
#             color:  #000000;
#         }    #T_07cf7b84_f8a9_11ea_9d3a_0c7a1589118crow2_col8 {
#             background-color:  #023d60;
#             color:  #f1f1f1;
#         }    #T_07cf7b84_f8a9_11ea_9d3a_0c7a1589118crow2_col9 {
#             background-color:  #f5eff6;
#             color:  #000000;
#         }    #T_07cf7b84_f8a9_11ea_9d3a_0c7a1589118crow2_col10 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_07cf7b84_f8a9_11ea_9d3a_0c7a1589118crow2_col11 {
#             background-color:  #b0c2de;
#             color:  #000000;
#         }    #T_07cf7b84_f8a9_11ea_9d3a_0c7a1589118crow2_col12 {
#             background-color:  #b3c3de;
#             color:  #000000;
#         }    #T_07cf7b84_f8a9_11ea_9d3a_0c7a1589118crow2_col13 {
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }    #T_07cf7b84_f8a9_11ea_9d3a_0c7a1589118crow2_col14 {
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }    #T_07cf7b84_f8a9_11ea_9d3a_0c7a1589118crow2_col15 {
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }    #T_07cf7b84_f8a9_11ea_9d3a_0c7a1589118crow2_col16 {
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }    #T_07cf7b84_f8a9_11ea_9d3a_0c7a1589118crow2_col17 {
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }    #T_07cf7b84_f8a9_11ea_9d3a_0c7a1589118crow2_col18 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_07cf7b84_f8a9_11ea_9d3a_0c7a1589118crow3_col0 {
#             background-color:  #c4cbe3;
#             color:  #000000;
#         }    #T_07cf7b84_f8a9_11ea_9d3a_0c7a1589118crow3_col1 {
#             background-color:  #4295c3;
#             color:  #000000;
#         }    #T_07cf7b84_f8a9_11ea_9d3a_0c7a1589118crow3_col2 {
#             background-color:  #c2cbe2;

# %% [markdown]
# ## 변수 가공없이 선형회귀 모델 학습

# %%
rmse = lambda y, p: np.sqrt(mean_squared_error(y, p))
rmlse = lambda y, p: np.sqrt(mean_squared_error(np.log1p(y), np.log1p(p)))

# %%
lr = LinearRegression()
lr.fit(df[num_cols], df[target_col])
df[pred_col] = lr.predict(df[num_cols])

print(f' RMSE:\t{rmse(df[target_col], df[pred_col]):12.2f}')
# Out:
#  RMSE:	        0.90

# %%
sns.pairplot(data=df, vars=[pred_col, target_col], size=4, plot_kws={'alpha': .5})

# %% [markdown]
# # 멱함수 분포 변수 `log1p` 변환(정규분호에 가깝게 변환)

# %%
df.nObserve.apply(np.log1p).hist(bins=50)

# %%
df.nDetect.apply(np.log1p).hist(bins=50)

# %%
lr = LinearRegression()
lr.fit(df[num_cols], np.log1p(df[target_col]))
#학습된 데이터를 다시 역변환 시켜준다
df[pred_col] = np.expm1(lr.predict(df[num_cols]))

print(f' RMSE:\t{rmse(df[target_col], df[pred_col]):12.2f}')
print(f'RMLSE:\t{rmlse(df[target_col], df[pred_col]):12.2f}')
# Out:
#  RMSE:	        0.93
# RMLSE:	        0.50

# %%
sns.pairplot(data=df, vars=[pred_col, target_col], size=4, plot_kws={'alpha': .5})

# %%
plt.figure(figsize=(8, 8))
plt.scatter(df[target_col], df[pred_col], alpha=.5)
plt.xlabel('r')
plt.ylabel('prediction')
plt.yscale('log')
plt.xscale('log')

# %%
df[num_cols].describe()
# Out:
#              dered_r
# count  320000.000000
# mean       17.615434
# std         1.473020
# min       -16.380230
# 25%        16.787138
# 50%        17.443415
# 75%        18.291078
# max        31.957200

# %%
df[['dered_r']] = df[['dered_r']].apply(np.log1p)
df[num_cols].describe()
# Out:
#              dered_r
# count  319994.000000
# mean        2.920986
# std         0.077618
# min         0.996157
# 25%         2.878480
# 50%         2.914708
# 75%         2.959645
# max         3.495210

# %%
sns.pairplot(data=df, vars=num_cols, size=5)

# %%
lr = LinearRegression()
lr.fit(df[num_cols], np.log1p(df[target_col]))
df[pred_col] = np.expm1(lr.predict(df[num_cols]))

print(f' RMSE:\t{rmse(df[target_col], df[pred_col]):12.2f}')
print(f'RMLSE:\t{rmlse(df[target_col], df[pred_col]):12.2f}')
# Out:
#  RMSE:	        0.93
# RMLSE:	        0.50

# %%
df.head()

# %% [markdown]
# # 정규화/스케일링

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
scaler = StandardScaler()
X = scaler.fit_transform(df[num_cols])

lr = LinearRegression()
lr.fit(X, np.log1p(df[target_col]))
df[pred_col] = np.expm1(lr.predict(X))

print(f' RMSE:\t{rmse(df[target_col], df[pred_col]):12.2f}')
print(f'RMLSE:\t{rmlse(df[target_col], df[pred_col]):12.2f}')
# Out:
#  RMSE:	        0.93
# RMLSE:	        0.50

# %%
scaler = MinMaxScaler()# min값과 max 값을 0 과 1 로 고정 시킨다. Ex) max=100이면 모두 100으로 나눈다.
X = scaler.fit_transform(df[num_cols])

lr = LinearRegression()
lr.fit(X, np.log1p(df[target_col]))
df[pred_col] = np.expm1(lr.predict(X))

print(f' RMSE:\t{rmse(df[target_col], df[pred_col]):12.2f}')
print(f'RMLSE:\t{rmlse(df[target_col], df[pred_col]):12.2f}')
# Out:
#  RMSE:	        0.93
# RMLSE:	        0.50
